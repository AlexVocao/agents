# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.12)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.12)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.

# %%
# First let's do an import. If you get an Import Error, see Q5 and then Q25 here: https://edwarddonner.com/faq

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file might have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to Q5 and Q25 in the FAQ at https://edwarddonner.com/faq
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "Tell me a fun fact"}]

# %%
messages

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 5.4 nano, an incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 5.4 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
question = response.choices[0].message.content
print(question)

# %%
# form a new messages list

messages = [{"role": "user", "content": question}]
messages

# %%
# Ask the model to answer the hard question

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
answer = response.choices[0].message.content
print(answer)
# Out:
# Here’s a strong **Agentic AI solution for Customer Support and Service Operations**.
#
# ## Solution concept: Autonomous Support Operations Agent
# An AI agent that can **handle, route, resolve, and follow up on customer support issues across multiple systems**, with human oversight only when needed.
#
# ### Core capabilities
# 1. **Intake and triage**
#    - Reads tickets, chat messages, emails, and call transcripts
#    - Classifies intent, urgency, sentiment, and customer value
#    - Routes issues to the correct queue or resolves them automatically
#
# 2. **Knowledge retrieval**
#    - Searches internal knowledge bases, SOPs, past tickets, and policy docs
#    - Pulls the most relevant answer or workflow for the issue
#
# 3. **Action execution**
#    - Performs routine tasks like:
#      - password resets
#      - order status lookups
#      - refund eligibility checks
#      - subscription changes
#      - account updates
#    - Uses APIs to interact with CRM, ticketing, billing, and order systems
#
# 4. **Response drafting**
#    - Generates personalized responses for customer emails or chats
#    - Adapts tone based on urgency, customer tier, and issue type
#    - Sends for human approval when confidence is low or risk is high
#
# 5. **Escalation management**
#    - Detects complex, sensitive, or high-value cases
#    - Escalates with a full summary, recommended next steps, and supporting evidence
#
# 6. **Case closure and follow-up**
#    - Updates ticket status
#    - Logs actions in CRM
#    - Sends follow-up messages and satisfaction surveys
#    - Summarizes the interaction for analytics and QA
#
# ---
#
# ## Typical workflow
# **Customer submits ticket → Agent classifies issue → Agent checks knowledge base and customer systems → Agent resolves or drafts reply → Human reviews if needed → Agent updates records and closes loop**
#
# ---
#
# ## Example use cases
# ### 1. Password reset
# - Verifies identity
# - Triggers reset workflow
# - Confirms completion to customer
# - Logs the action automatically
#
# ### 2. Order status inquiry
# - Pulls order data from ERP/e-commerce system
# - Provides current shipping status and ETA
# - Flags delays proactively if found
#
# ### 3. Billing dispute
# - Reviews invoice, payment history, and policy rules
# - Suggests resolution options
# - Escalates if fraud or manual review is required
#
# ### 4. VIP customer issue
# - Detects high-value account
# - Prioritizes ticket
# - Routes to senior support or success manager
# - Adds urgency notes and summary
#
# ---
#
# ## Architecture overview
# ### Inputs
# - Email
# - Chat
# - Voice transcript
# - Web forms
# - Social/support channels
#
# ### Connected systems
# - CRM: Salesforce, HubSpot
# - Ticketing: Zendesk, ServiceNow, Freshdesk
# - Knowledge base: Confluence, Notion, SharePoint
# - Orders/billing: ERP, billing platform, OMS
# - Messaging: Slack, Teams, customer chat platform
#
# ### Agent layers
# 1. **Orchestration agent**
#    Decides the next step: answer, ask follow-up, escalate, or execute task
#
# 2. **Retrieval agent**
#    Finds the right policy, answer, or historical precedent
#
# 3. **Action agent**
#    Calls APIs to perform approved operational steps
#
# 4. **Review/guardrail agent**
#    Checks policy compliance, confidence, and risk before customer-facing actions
#
# ---
#
# ## Guardrails
# To keep it safe and usable:
# - Human approval for refunds, account changes, cancellations, and sensitive cases
# - Confidence thresholds for automatic responses
# - Policy-based refusal and escalation for legal, security, or complaint-heavy issues
# - Full audit trail of every action
# - Role-based access control for tools and data
# - PII redaction in logs and summaries
#
# ---
#
# ## Business value
# ### Measurable outcomes
# - Faster first response time
# - Higher first-contact resolution
# - Lower average handle time
# - Reduced ticket backlog
# - Better agent productivity
# - Improved customer satisfaction
#
# ### Cost impact
# - Automates repetitive tickets
# - Reduces manual lookup and copy-paste work
# - Helps smaller teams handle higher volumes
#
# ---
#
# ## Implementation roadmap
# ### Phase 1: Assist
# - Agent drafts replies and summarizes tickets
# - Human approves everything
#
# ### Phase 2: Partial automation
# - Agent auto-resolves simple, low-risk cases
# - Human handles exceptions
#
# ### Phase 3: Autonomous operations
# - Agent manages end-to-end resolution for routine workflows
# - Humans focus on escalations and complex customer issues
#
# ---
#
# ## Best initial pilot
# Start with 3–5 high-volume, low-risk ticket types:
# - password resets
# - order status checks
# - invoice explanations
# - account update requests
# - FAQ-style inquiries
#
# These are ideal because they are:
# - repetitive
# - easy to validate
# - low risk
# - high volume
#
# ---
#
# ## One-line proposal
# **Build an Autonomous Support Operations Agent that triages incoming customer issues, resolves routine cases across CRM/ticketing/order systems, drafts responses for approval when needed, and escalates complex cases with complete context.**
#
# If you want, I can turn this into one of these next:
# 1. a **slide-ready proposal**,
# 2. a **solution architecture diagram in text**, or
# 3. a **business case with ROI assumptions**.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Here’s a strong **Agentic AI solution for Customer Support and Service Operations**.
#
# ## Solution concept: Autonomous Support Operations Agent
# An AI agent that can **handle, route, resolve, and follow up on customer support issues across multiple systems**, with human oversight only when needed.
#
# ### Core capabilities
# 1. **Intake and triage**
#    - Reads tickets, chat messages, emails, and call transcripts
#    - Classifies intent, urgency, sentiment, and customer value
#    - Routes issues to the correct queue or resolves them automatically
#
# 2. **Knowledge retrieval**
#    - Searches internal knowledge bases, SOPs, past tickets, and policy docs
#    - Pulls the most relevant answer or workflow for the issue
#
# 3. **Action execution**
#    - Performs routine tasks like:
#      - password resets
#      - order status lookups
#      - refund eligibility checks
#      - subscription changes
#      - account updates
#    - Uses APIs to interact with CRM, ticketing, billing, and order systems
#
# 4. **Response drafting**
#    - Generates personalized responses for customer emails or chats
#    - Adapts tone based on urgency, customer tier, and issue type
#    - Sends for human approval when confidence is low or risk is high
#
# 5. **Escalation management**
#    - Detects complex, sensitive, or high-value cases
#    - Escalates with a full summary, recommended next steps, and supporting evidence
#
# 6. **Case closure and follow-up**
#    - Updates ticket status
#    - Logs actions in CRM
#    - Sends follow-up messages and satisfaction surveys
#    - Summarizes the interaction for analytics and QA
#
# ---
#
# ## Typical workflow
# **Customer submits ticket → Agent classifies issue → Agent checks knowledge base and customer systems → Agent resolves or drafts reply → Human reviews if needed → Agent updates records and closes loop**
#
# ---
#
# ## Example use cases
# ### 1. Password reset
# - Verifies identity
# - Triggers reset workflow
# - Confirms completion to customer
# - Logs the action automatically
#
# ### 2. Order status inquiry
# - Pulls order data from ERP/e-commerce system
# - Provides current shipping status and ETA
# - Flags delays proactively if found
#
# ### 3. Billing dispute
# - Reviews invoice, payment history, and policy rules
# - Suggests resolution options
# - Escalates if fraud or manual review is required
#
# ### 4. VIP customer issue
# - Detects high-value account
# - Prioritizes ticket
# - Routes to senior support or success manager
# - Adds urgency notes and summary
#
# ---
#
# ## Architecture overview
# ### Inputs
# - Email
# - Chat
# - Voice transcript
# - Web forms
# - Social/support channels
#
# ### Connected systems
# - CRM: Salesforce, HubSpot
# - Ticketing: Zendesk, ServiceNow, Freshdesk
# - Knowledge base: Confluence, Notion, SharePoint
# - Orders/billing: ERP, billing platform, OMS
# - Messaging: Slack, Teams, customer chat platform
#
# ### Agent layers
# 1. **Orchestration agent**
#    Decides the next step: answer, ask follow-up, escalate, or execute task
#
# 2. **Retrieval agent**
#    Finds the right policy, answer, or historical precedent
#
# 3. **Action agent**
#    Calls APIs to perform approved operational steps
#
# 4. **Review/guardrail agent**
#    Checks policy compliance, confidence, and risk before customer-facing actions
#
# ---
#
# ## Guardrails
# To keep it safe and usable:
# - Human approval for refunds, account changes, cancellations, and sensitive cases
# - Confidence thresholds for automatic responses
# - Policy-based refusal and escalation for legal, security, or complaint-heavy issues
# - Full audit trail of every action
# - Role-based access control for tools and data
# - PII redaction in logs and summaries
#
# ---
#
# ## Business value
# ### Measurable outcomes
# - Faster first response time
# - Higher first-contact resolution
# - Lower average handle time
# - Reduced ticket backlog
# - Better agent productivity
# - Improved customer satisfaction
#
# ### Cost impact
# - Automates repetitive tickets
# - Reduces manual lookup and copy-paste work
# - Helps smaller teams handle higher volumes
#
# ---
#
# ## Implementation roadmap
# ### Phase 1: Assist
# - Agent drafts replies and summarizes tickets
# - Human approves everything
#
# ### Phase 2: Partial automation
# - Agent auto-resolves simple, low-risk cases
# - Human handles exceptions
#
# ### Phase 3: Autonomous operations
# - Agent manages end-to-end resolution for routine workflows
# - Humans focus on escalations and complex customer issues
#
# ---
#
# ## Best initial pilot
# Start with 3–5 high-volume, low-risk ticket types:
# - password resets
# - order status checks
# - invoice explanations
# - account update requests
# - FAQ-style inquiries
#
# These are ideal because they are:
# - repetitive
# - easy to validate
# - low risk
# - high volume
#
# ---
#
# ## One-line proposal
# **Build an Autonomous Support Operations Agent that triages incoming customer issues, resolves routine cases across CRM/ticketing/order systems, drafts responses for approval when needed, and escalates complex cases with complete context.**
#
# If you want, I can turn this into one of these next:
# 1. a **slide-ready proposal**,
# 2. a **solution architecture diagram in text**, or
# 3. a **business case with ROI assumptions**.

# %%
message = f"""
Here is a question:
{question}

And here is a possible answer that might be correct or incorrect:
{answer}

Please evaluate if the answer is correct or incorrect.
"""

print(message)

# %%
messages = [{"role": "user", "content": message}]
response = openai.chat.completions.create(model="gpt-5.4", messages=messages)
print(response.choices[0].message.content)

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Pick a business area that might be worth exploring for an Agentic AI opportunity."}]

# Then make the first call:

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)

# Then read the business idea:

business_area = response.choices[0].message.content

# And repeat! In the next message, include the business area within the message
messages = [{"role": "user", "content": f"Pick a pain-point in the {business_area} industry."}]

# Then make the first call:

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)

messages = [{"role": "user", "content": f"Propose the Agentic AI solution for the {business_area} industry."}]

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)

display(Markdown(response.choices[0].message.content))
# Out:
# A strong Agentic AI opportunity in **mid-market SaaS customer support operations** is to build an **AI Support Operations Agent** that can **triage, investigate, resolve, and escalate tickets across systems** with human oversight.
#
# ## Proposed solution: AI Support Operations Agent
#
# ### Core objective
# Reduce support workload and improve resolution speed by automating the full lifecycle of common customer issues:
# - classify incoming requests
# - identify account/context
# - fetch relevant policy or knowledge base info
# - take approved actions in tools like Zendesk, Intercom, Salesforce, Jira, Slack, and billing systems
# - update the customer and internal teams
# - escalate edge cases to humans
#
# ---
#
# ## Best initial wedge
# Start with:
#
# ### **Billing and account access issues**
# This is the best entry point because:
# - high volume
# - repeatable workflows
# - clear rules and guardrails
# - strong customer pain
# - measurable ROI
# - low ambiguity compared with more complex technical troubleshooting
#
# Examples:
# - “I was charged twice”
# - “I can’t log in”
# - “My plan downgrade didn’t apply”
# - “Please resend invoice”
# - “My user was locked out”
# - “Why was my card declined?”
#
# ---
#
# ## What the agent does
#
# ### 1. Intake and triage
# - read incoming ticket/chat/email
# - classify issue type, severity, sentiment, and urgency
# - detect whether it’s billing, auth/access, product bug, outage, or general inquiry
# - route to the right queue or handle automatically
#
# ### 2. Context gathering
# The agent checks:
# - CRM customer tier and contract
# - billing history and invoices
# - authentication/user status
# - known outages/incidents
# - product entitlements
# - previous tickets and conversation history
#
# ### 3. Resolution planning
# It decides whether to:
# - answer from KB
# - take an automated action
# - request missing info
# - ask for approval
# - escalate to a human
#
# ### 4. Action execution
# Within policy limits, the agent can:
# - update ticket status
# - reset or unlock accounts
# - resend invoices
# - issue refunds up to a threshold
# - apply credits
# - create internal Jira tasks
# - notify finance/engineering/on-call
# - send customer follow-ups
#
# ### 5. Customer communication
# It can:
# - ask for missing details
# - provide step-by-step instructions
# - send updates during investigation
# - confirm resolution
# - close the loop politely and consistently
#
# ---
#
# ## Key system architecture
#
# ### Inputs
# - Zendesk / Intercom tickets
# - email and chat transcripts
# - CRM records
# - billing platform data
# - product usage/auth logs
# - knowledge base / help center
# - outage/status page data
#
# ### Agent orchestration layer
# - issue classifier
# - context retrieval agent
# - policy/rules engine
# - action executor
# - escalation manager
# - communication generator
#
# ### Controls
# - confidence thresholds
# - action approval limits
# - audit logging
# - human-in-the-loop for exceptions
# - role-based permissions
# - fallback to manual handling
#
# ---
#
# ## Example workflow: billing dispute
# 1. Ticket arrives: “I was charged twice.”
# 2. Agent classifies as billing issue.
# 3. Checks billing system and finds duplicate authorization/charge.
# 4. Verifies customer tier and refund eligibility.
# 5. If within policy, issues refund.
# 6. Updates ticket and sends apology + confirmation.
# 7. Closes ticket or routes to finance if outside policy.
#
# ---
#
# ## Example workflow: account access issue
# 1. Customer says they cannot log in.
# 2. Agent checks whether account is locked, password reset pending, SSO issue, or license expired.
# 3. If lockout: unlocks account.
# 4. If expired license: notifies customer success and sends renewal workflow.
# 5. If SSO issue: creates Jira ticket and informs the customer.
# 6. Logs every action.
#
# ---
#
# ## Why this is a good business opportunity
#
# ### Business value
# - lower cost per ticket
# - faster first response and resolution times
# - improved CSAT and retention
# - reduced agent burnout
# - better support consistency
# - scalable without linear headcount growth
#
# ### Technical fit
# - workflows are structured enough for automation
# - many decisions can be policy-driven
# - lots of API-accessible systems
# - human review can handle edge cases
#
# ### Market fit
# Mid-market SaaS companies often have:
# - enough ticket volume to justify automation
# - enough systems complexity to benefit from orchestration
# - not enough support headcount to solve manually
# - strong motivation to improve support efficiency
#
# ---
#
# ## MVP recommendation
#
# ### Phase 1: Assistive agent
# - triage and summarize tickets
# - suggest next best action
# - draft responses
# - recommend routing and escalation
#
# ### Phase 2: Semi-autonomous agent
# - execute low-risk actions automatically
# - handle billing/account access tickets end-to-end
# - ask for approvals on refunds/credits above thresholds
#
# ### Phase 3: Autonomous support ops layer
# - expand to more issue types
# - optimize across multiple systems
# - proactive detection of incidents and customer impact
# - automate follow-ups and internal coordination
#
# ---
#
# ## Success metrics
# - ticket deflection rate
# - first response time
# - average resolution time
# - % tickets auto-resolved
# - CSAT
# - escalation rate
# - refund/credit processing time
# - support cost per ticket
#
# ---
#
# ## Guardrails
# To keep it safe and enterprise-ready:
# - limit refund/credit authority
# - require approval for policy exceptions
# - log all actions
# - maintain full conversation/audit trail
# - use confidence scoring
# - route sensitive cases to humans
# - enforce compliance and access controls
#
# ---
#
# ## Positioning statement
# **“An AI support operations agent that autonomously resolves repetitive customer issues across billing, account access, and support systems while escalating exceptions to humans.”**
#
# If you want, I can turn this into one of the following:
# 1. a **product one-pager**
# 2. a **solution architecture diagram in text**
# 3. a **go-to-market strategy**
# 4. a **business case / ROI model**
